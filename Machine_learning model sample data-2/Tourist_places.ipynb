# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("Top indian places to visit.csv")

# %%
df
# Out:
#      Unnamed: 0      Zone           State         City  \
# 0             0  Northern           Delhi        Delhi
# 1             1  Northern           Delhi        Delhi
# 2             2  Northern           Delhi        Delhi
# 3             3  Northern           Delhi        Delhi
# 4             4  Northern           Delhi        Delhi
# ..          ...       ...             ...          ...
# 320         320   Western         Gujarat  Gandhinagar
# 321         321   Central   Uttar Pradesh         Agra
# 322         322   Central  Madhya Pradesh       Bhopal
# 323         323  Northern       Rajasthan       Jaipur
# 324         324  Northern       Rajasthan       Jaipur
#
#                              Name          Type Establishment Year  \
# 0                      India Gate  War Memorial               1921
# 1                  Humayun's Tomb          Tomb               1572
# 2               Akshardham Temple        Temple               2005
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325 entries, 0 to 324
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Unnamed: 0                        325 non-null    int64
#  1   Zone                              325 non-null    object
#  2   State                             325 non-null    object
#  3   City                              325 non-null    object
#  4   Name                              325 non-null    object
#  5   Type                              325 non-null    object
#  6   Establishment Year                325 non-null    object
#  7   time needed to visit in hrs       325 non-null    float64
#  8   Google review rating              325 non-null    float64
#  9   Entrance Fee in INR               325 non-null    int64
#  10  Airport with 50km Radius          325 non-null    object
# ...

# %%
df1=df[["time needed to visit in hrs","Google review rating","Number of google review in lakhs","Entrance Fee in INR"]]

# %%
df1
# Out:
#      time needed to visit in hrs  Google review rating  \
# 0                            0.5                   4.6
# 1                            2.0                   4.5
# 2                            5.0                   4.6
# 3                            2.0                   4.1
# 4                            2.0                   4.2
# ..                           ...                   ...
# 320                          3.0                   4.6
# 321                          2.0                   4.5
# 322                          2.0                   4.7
# 323                          2.0                   4.4
# 324                          2.0                   4.5
#
#      Number of google review in lakhs  Entrance Fee in INR
# 0                                2.60                    0
# 1                                0.40                   30
# 2                                0.40                   60
# 3                                0.27                   50
# ...

# %%
df1.corr()
# Out:
#                                   time needed to visit in hrs  \
# time needed to visit in hrs                          1.000000
# Google review rating                                -0.195736
# Number of google review in lakhs                    -0.010589
# Entrance Fee in INR                                  0.281676
#
#                                   Google review rating  \
# time needed to visit in hrs                  -0.195736
# Google review rating                          1.000000
# Number of google review in lakhs              0.067170
# Entrance Fee in INR                          -0.048511
#
#                                   Number of google review in lakhs  \
# time needed to visit in hrs                              -0.010589
# Google review rating                                      0.067170
# Number of google review in lakhs                          1.000000
# Entrance Fee in INR                                       0.045612
#
# ...

# %%
df1.corr()
# Out:
#                                   time needed to visit in hrs  \
# time needed to visit in hrs                          1.000000
# Google review rating                                -0.195736
# Number of google review in lakhs                    -0.010589
# Entrance Fee in INR                                  0.281676
#
#                                   Google review rating  \
# time needed to visit in hrs                  -0.195736
# Google review rating                          1.000000
# Number of google review in lakhs              0.067170
# Entrance Fee in INR                          -0.048511
#
#                                   Number of google review in lakhs  \
# time needed to visit in hrs                              -0.010589
# Google review rating                                      0.067170
# Number of google review in lakhs                          1.000000
# Entrance Fee in INR                                       0.045612
#
# ...

# %%
df1.value_counts()
# Out:
# time needed to visit in hrs  Google review rating  Number of google review in lakhs  Entrance Fee in INR
# 1.0                          4.5                   0.01                              0                      3
#                              4.7                   0.49                              0                      2
# 2.0                          4.6                   0.10                              0                      2
# 1.0                          4.5                   0.59                              0                      2
#                                                    0.09                              0                      2
#                                                                                                            ..
# 1.5                          4.2                   0.95                              0                      1
# ...

# %%
df1.shape
# Out:
# (325, 4)

# %%
df1["Entrance Fee in INR"].value_counts()
# Out:
# Entrance Fee in INR
# 0       183
# 50       21
# 20       19
# 30       13
# 10       12
# 100       8
# 500       7
# 40        7
# 25        6
# 300       5
# 15        5
# 150       4
# 35        4
# 200       4
# 60        4
# 1149      2
# 2500      2
# 80        2
# 250       2
# 1500      2
# 1100      1
# 650       1
# 65        1
# 5         1
# 3500      1
# 75        1
# 750       1
# 350       1
# 7500      1
# 1150      1
# 550       1
# 70        1
# 890       1
# Name: count, dtype: int64

# %%
newdf=df1[(df1["Entrance Fee in INR"]!=0)]

# %%
newdf
# Out:
#      time needed to visit in hrs  Google review rating  \
# 1                            2.0                   4.5
# 2                            5.0                   4.6
# 3                            2.0                   4.1
# 4                            2.0                   4.2
# 7                            2.0                   4.5
# ..                           ...                   ...
# 318                          2.0                   4.4
# 321                          2.0                   4.5
# 322                          2.0                   4.7
# 323                          2.0                   4.4
# 324                          2.0                   4.5
#
#      Number of google review in lakhs  Entrance Fee in INR
# 1                                0.40                   30
# 2                                0.40                   60
# 3                                0.27                   50
# 4                                0.31                   15
# ...

# %%
x=newdf.drop(columns=["Entrance Fee in INR"])

# %%
y=newdf["Entrance Fee in INR"]

# %%
x.shape
# Out:
# (142, 3)

# %%
y.shape
# Out:
# (142,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.40)

# %%
x_train.shape
# Out:
# (85, 3)

# %%
y_train.shape
# Out:
# (85,)

# %%
Lmodel=LinearRegression()
Lmodel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
Lmodel.score(x_train,y_train)
# Out:
# 0.09845338462673692

# %%
Lmodel.score(x_test,y_test)
# Out:
# -0.0009492311911691864

# %%
from sklearn.linear_model import Lasso
reg2= Lasso(alpha=25,max_iter=100,tol=0.3)
reg2.fit(x_train,y_train)
# Out:
# Lasso(alpha=25, max_iter=100, tol=0.3)

# %%
reg2.score(x_test,y_test)
# Out:
# 0.045699371084498286

# %%
reg2.score(x_train,y_train)
# Out:
# 0.08126795333592995
